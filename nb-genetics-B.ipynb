# %%
res     = [0.25,0.5,0.75,1.0,2.0,3.0,5.0]

level10 = [5030.5834045]*len(res)
data10  = [132183.84024013922, 97881.0993989, 63990.948366, 103580.43137, 100509.641076,94161.2128884,64063.6815099]

level25 = [2303.4226898657857]*len(res)
data25 = [60715.5933215,26318.0289947,24785.4800698,36411.7330138,29650.0624531,12625.3222621,10728.9297456]

level50 = [7215.541117]*len(res)
data50  = [67079.635674,33951.0286976,26969.959766,18899.6590669,15017.0532141,11944.8640889,10643.5404109]

level90 = [3751.70562922]*len(res)
data90  = [27793.5772492, 16437.0609914, 9903.04831982, 7491.11136329, 6831.84480323, 4958.2025656,4915.8138789]

level160 = [108.14]*len(res)
data160  = [1985.44754885,873.489757197,466.105936827,428.860935363,304.509882203,221.225679839,214.550898954]

level190 = [77.1452858]*len(res)
data190  = [1557.12112093,471.693206604,438.944086338,325.682839804,348.818305652,198.23580426,169.378737382]


def plot(level,data,title):
    pyplot.figure(figsize=(8,3))
    pyplot.plot(res,level,'-o')
    pyplot.plot(res,data,'o-')
    pyplot.title(title)
    pyplot.xlabel('resolution (nm)')
    pyplot.show()

plot(level10,data10,'focus at layer 10')
plot(level25,data25,'focus at layer 25')
plot(level50,data50,'focus at layer 50')
plot(level90,data90,'focus at layer 90')
plot(level160,data160,'focus at layer 160')
plot(level190,data190,'focus at layer 190')
