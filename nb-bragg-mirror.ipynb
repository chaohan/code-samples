# %% [markdown]
# This is a test application for the stack module. Computed data is in agreement with http://www.batop.de/information/r_Bragg.html

# %%
from stack import *
nh=3.49; nl=2.95
N=21; L=1064.0/(4.0*nh); L1 = 1064.0/(4.0*nl);dL=0.0
mirror = random_stack(N,1.0,nh,dL,L,L1=L1)
mirror.set_refr(range(2,22,2),nl)

mirror.plot()

# %%
mirror.scan('reflection',[950,1200],500)

# %%
mirror.get_reflection(1064)
# Out:
# 0.96104343028165717
