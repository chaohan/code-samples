# %%
def produce(path):
    files = map(lambda f:path+f,[
        'inv-focus0.npy',
        'inv-focus.npy'])
#        'inv-focus-min.npy',
#        'inv-focus-field.npy',
#        'inv-focus-field+min.npy'])

    legends = ['focus a0 before entrance', 
           'focus a0 inside']
#           'focus a0 inside + min',
#           'focus field inside',
#           'focus field inside + min']

    pyplot.figure(figsize=(18, 6))
    pyplot.xlabel('layer number',fontsize=20)
    pyplot.ylabel('population inversion',fontsize=20)

    data = map(np.load,files)
    for j in range(len(data)):
        pyplot.plot(data[j][:,0],data[j][:,1],'o-')
        #legends[j] += str("{:7.4f}".format(sum(data[j][1:50])/sum(data[j][100:150])))
    pyplot.legend(legends,fontsize=22)
    pyplot.show()
    #return data

locations = ['200@10/', '200@50/','200@90/','200@125/','200@160/','200@190/']
def plot_figures(case):
    for location in locations: produce('io_files/'+case+location)

# %%
case1 = '1600nm-100nm-100um-025nm-central/'
case2 = '1600nm-100nm-100um-05nm-central/'
case3 = '1600nm-100nm-100um-1nm-central/'
case4 = '1600nm-100nm-100um-1.5nm-central/'

# %%
plot_figures(case1)

# %%
plot_figures(case2)

# %%
plot_figures(case3)

# %%
plot_figures(case4)
